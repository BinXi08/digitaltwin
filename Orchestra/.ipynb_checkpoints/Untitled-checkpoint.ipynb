# %%
import os

# %%
os.system('java -cp orchestra2022.jar orchestra2.RunBatch concert.xml')
# Out:
# Running concert.xml .....
# Scanning file: chemistry1.inp
# Including file: objects2021.txt
# Scanning file: chemistry1.inp
# Including file: objects2021.txt
# Including file: chemistry1.inp
# Including file: objects2021.txt
# 	Reading variables .... 0.116 s
# input.dat 501 datapoints.
# Try a first calculation with iia switched off....
# Parsing expressions of chemistry1.inp.....
# Optimizing expressions of chemistry1.inp.....
# 0.661 sec.
# 1511 variables, 4537 expressions, 5 equations.
# First calculation was successful!
# Repeat calculation with iia switched on..
# Switching on: totvolume: 0.1
# Switching on: I: 0.1
# Switching on: pH: 7.0
# This was successful!!
# chemistry1.inp: Improving start estimations:.
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&|
# Trying better start estimations was successful!!
# chemistry1.inp: Improving start estimations:.
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&|
# Trying better start estimations was successful!!
# chemistry1.inp: Improving start estimations:.
# ...
